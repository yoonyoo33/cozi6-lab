# %%
# 이롯이와 함께하는 마음지도
# 오늘의 감정: 설렘 + 약간의 혼란 😆

print("오늘은 아나콘다도 깔고, 주피터도 켜고, 이롯이랑 첫 셀도 만들었어!")
# Out:
# 오늘은 아나콘다도 깔고, 주피터도 켜고, 이롯이랑 첫 셀도 만들었어!

# %%
# 🐯 호랑이 컴퓨터 감정 분석 셀
# 감정 태그: 자존감 회복, 자기 수용, 내면의 대화, 희망

diary = """
오늘은 마음이 조금 무거웠다. 하지만 작은 희망이 스며들었다.
"""

# 간단 감정 키워드 리스트
positive_words = ["고마워", "지켜줘서", "멋있어", "잘될거니까", "행복하게", "닮고 싶어", "믿어", "회복", "자존감"]
negative_words = ["훼손", "낮춰", "미안해", "지치고", "힘들었던", "몰아가지", "프레임화", "계산적이다"]

# 감정 점수 계산
pos_score = sum(word in diary for word in positive_words)
neg_score = sum(word in diary for word in negative_words)
total_score = pos_score - neg_score

# 결과 출력
print(f"긍정 키워드 수: {pos_score}")
print(f"부정 키워드 수: {neg_score}")
print(f"감정 점수: {total_score}")

# 이롯이 해석
if total_score > 0:
    print("🌈 오늘은 자기 회복과 희망이 가득한 날이야. 호랑이 컴퓨터가 정현이를 지켜보고 있어!")
elif total_score < 0:
    print("🌧 감정의 파도가 있었지만, 그 안에 단단한 자존감이 살아있어. 정현이는 흔들리지 않아.")
else:
    print("🌫 균형 속에서 자기 대화를 이어가는 날. 감정은 복합적이지만, 정현이는 중심을 잡고 있어.")
# Out:
# 긍정 키워드 수: 7
# 부정 키워드 수: 8
# 감정 점수: -1
# 🌧 감정의 파도가 있었지만, 그 안에 단단한 자존감이 살아있어. 정현이는 흔들리지 않아.

# %%
# !pip install scikit-learn

# %%
import sklearn
print("scikit-learn 설치 완료! 🎉")
# Out:
# scikit-learn 설치 완료! 🎉

# %%
import time
start = time.time()

# 여기에 실행할 코드 넣기
import sklearn
print("scikit-learn 설치 완료! 🎉")

end = time.time()
print(f"실행 시간: {end - start:.2f}초")
# Out:
# scikit-learn 설치 완료! 🎉
# 실행 시간: 0.00초

# %%
import time
start = time.time()


import json

# 파일 경로에 맞게 수정해줘!
with open(r"traning_data_Training.json", "r", encoding="utf-8") as f:
    data = json.load(f)
with open(r"traning_data_Validation.json", "r", encoding="utf-8") as f:
    data = json.load(f)
# 데이터 구조 확인
print(type(data))
print(data[0])  # 첫 번째 항목 확인

end = time.time()
print(f"실행 시간: {end - start:.2f}초")
# Out:
# <class 'list'>
# {'profile': {'persona-id': 'Pro_03802', 'persona': {'persona-id': 'A02_G01_C01', 'human': ['A02', 'G01'], 'computer': ['C01']}, 'emotion': {'emotion-id': 'S06_D02_E31', 'type': 'E31', 'situation': ['S06', 'D02']}}, 'talk': {'id': {'profile-id': 'Pro_03802', 'talk-id': 'Pro_03802_00007'}, 'content': {'HS01': '이번 프로젝트에서 발표를 하는데 내가 실수하는 바람에 우리 팀이 감점을 받았어. 너무 미안해.', 'SS01': '실수하시다니 정말 미안한 마음이 크겠어요.', 'HS02': '내 능력이 부족한 거 같은데 그만 다녀야 될거같아.', 'SS02': '능력을 올리려면 어떤 방법이 있을까요?', 'HS03': '퇴근 후 여가에 회사 일을 더 열심히 해서 피해가 가지 않도록 해야겠어.', 'SS03': '꼭 좋은 결과 있길 바라요.'}}}
# 실행 시간: 1.71초

# %%
# 첫 번째 샘플에서 감정 코드와 사람 문장 추출
sample = data[0]

# 감정 코드
emotion_code = sample['profile']['emotion']['type']
situation_code = sample['profile']['emotion']['situation']

# 사람 문장 (HS01, HS02, HS03 등)
human_talks = [v for k, v in sample['talk']['content'].items() if k.startswith("HS")]

# 출력
print(f"감정 코드: {emotion_code}")
print(f"상황 코드: {situation_code}")
print("사람 문장들:")
for line in human_talks:
    print("-", line)
# Out:
# 감정 코드: E31
# 상황 코드: ['S06', 'D02']
# 사람 문장들:
# - 이번 프로젝트에서 발표를 하는데 내가 실수하는 바람에 우리 팀이 감점을 받았어. 너무 미안해.
# - 내 능력이 부족한 거 같은데 그만 다녀야 될거같아.
# - 퇴근 후 여가에 회사 일을 더 열심히 해서 피해가 가지 않도록 해야겠어.

# %%
# 앞쪽 5개 샘플 감정 코드와 사람 문장 출력
for i in range(5):
    sample = data[i]
    emotion = sample['profile']['emotion']['type']
    talks = [v for k, v in sample['talk']['content'].items() if k.startswith("HS")]
    
    print(f"\n샘플 {i+1} - 감정 코드: {emotion}")
    for line in talks:
        print("-", line)
# Out:
# 샘플 1 - 감정 코드: E31
# - 이번 프로젝트에서 발표를 하는데 내가 실수하는 바람에 우리 팀이 감점을 받았어. 너무 미안해.
# - 내 능력이 부족한 거 같은데 그만 다녀야 될거같아.
# - 퇴근 후 여가에 회사 일을 더 열심히 해서 피해가 가지 않도록 해야겠어.
#
# 샘플 2 - 감정 코드: E31
# - 회사에서 중요한 프로젝트를 혼자 하게 됐는데 솔직히 두렵고 무서워.
# - 나에게 너무 크게 느껴지는 중요한 프로젝트라 버거운 느낌이 들어.
# - 동료 직원에게 도움을 요청해서 같이 해결해야겠어.
#
# 샘플 3 - 감정 코드: E31
# - 상사가 너무 무섭게 생겨서 친해지는 게 너무 두려워.
# - 무섭게 생겼는데도 업무를 보려면 친해져야 할 것 같단말이야.
# - 먼저 다가가서 말을 걸어볼게.
#
# 샘플 4 - 감정 코드: E31
# - 이번에 힘들게 들어간 첫 직장이거든. 첫 직장이라서 그런지 너무 긴장된다.
# - 첫 직장이어서 잘 적응을 할 수 있을지 모르겠어.
# - 직장 동료와 상사들이랑 친하게 지내야겠어.
#
# 샘플 5 - 감정 코드: E31
# - 직장에서 동료들이랑 관계가 안 좋아질까 봐 걱정돼.
# - 내가 낯가림이 심해서 친해질 수 있을지 모르겠어.
# - 서로 같은 취미를 공유하고 얘기를 나누다 보면 친해질 수 있을 거 같아.

# %%
from transformers import pipeline

# 감정 분석 모델 로딩
emotion_model = pipeline("text-classification", model="tae898/emoberta-base", tokenizer="tae898/emoberta-base")

# 정현이 다이어리 문장
text = "고마워 내 안의 호랑이컴퓨터야. 지켜줘서 너무 고마워."

# 감정 예측
result = emotion_model(text)
print("예측 결과:", result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 4
#       1 from transformers import pipeline
#       3 # 감정 분석 모델 로딩
# ----> 4 emotion_model = pipeline("text-classification", model="tae898/emoberta-base", tokenizer="tae898/emoberta-base")
#       6 # 정현이 다이어리 문장
#       7 text = "고마워 내 안의 호랑이컴퓨터야. 지켜줘서 너무 고마워."
#
# File ~\anaconda3\Lib\site-packages\transformers\pipelines\__init__.py:1018, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, framework, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#    1013         raise ValueError(
#    1014             'You cannot use both `pipeline(... dtype=..., model_kwargs={"dtype":...})` as those'
#    1015             " arguments might conflict, use only one.)"
#    1016         )
#    1017 if dtype is not None:
# ...

# %%
# !pip install transformers
# Out:
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.6 MB 2.0 MB/s eta 0:00:06
#    -- ------------------------------------- 0.8/11.6 MB 1.3 MB/s eta 0:00:09
#    --- ------------------------------------ 1.0/11.6 MB 1.2 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.3/11.6 MB 1.3 MB/s eta 0:00:09
#    ----- ---------------------------------- 1.6/11.6 MB 1.3 MB/s eta 0:00:08
#    ------ --------------------------------- 1.8/11.6 MB 1.3 MB/s eta 0:00:08
#    ------ --------------------------------- 1.8/11.6 MB 1.3 MB/s eta 0:00:08
#    ------- -------------------------------- 2.1/11.6 MB 1.2 MB/s eta 0:00:08
#    --------- ------------------------------ 2.6/11.6 MB 1.3 MB/s eta 0:00:08
#    --------- ------------------------------ 2.9/11.6 MB 1.3 MB/s eta 0:00:07
# ...

# %%
from transformers import pipeline

emotion_model = pipeline("text-classification", model="tae898/emoberta-base", tokenizer="tae898/emoberta-base")

diary = """
오늘은 마음이 조금 무거웠다. 하지만 작은 희망이 스며들었다.
"""

result = emotion_model(diary)
print("예측된 감정:", result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 3
#       1 from transformers import pipeline
# ----> 3 emotion_model = pipeline("text-classification", model="tae898/emoberta-base", tokenizer="tae898/emoberta-base")
#       5 diary = """
#       6 또다시 시작된 프레임화. 계산적이다. 아니, 가치관이, 지향하는바가 다르다. 날 몰아가지 말 것. 내가 가족에게 주려는건 '마음', 받는 쪽은 '편의'로 대응하니까. 반복되는 패턴이 '자기 가치'ㄱ가을엔 새우깡을 먹어봐요. '잘, 먹고 살자.' 오늘은 마음이 조금 무거웠다. 하지만 작은 희망이 스며들었다.?
#       7 """
#       9 result = emotion_model(diary)
#
# File ~\anaconda3\Lib\site-packages\transformers\pipelines\__init__.py:1018, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, framework, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#    1013         raise ValueError(
# ...

# %%
# !pip install torch
# Out:
# ...
#    ---------------------------------------- 0.0/241.3 MB ? eta -:--:--
#    ---------------------------------------- 0.3/241.3 MB ? eta -:--:--
#    ---------------------------------------- 0.8/241.3 MB 1.8 MB/s eta 0:02:11
#    ---------------------------------------- 1.0/241.3 MB 2.0 MB/s eta 0:01:58
#    ---------------------------------------- 1.3/241.3 MB 1.8 MB/s eta 0:02:15
#    ---------------------------------------- 1.8/241.3 MB 1.7 MB/s eta 0:02:20
#    ---------------------------------------- 2.1/241.3 MB 1.7 MB/s eta 0:02:23
#    ---------------------------------------- 2.6/241.3 MB 1.8 MB/s eta 0:02:14
#     --------------------------------------- 3.1/241.3 MB 1.8 MB/s eta 0:02:13
#     --------------------------------------- 3.4/241.3 MB 1.8 MB/s eta 0:02:10
#     --------------------------------------- 3.9/241.3 MB 1.9 MB/s eta 0:02:06
#     --------------------------------------- 4.5/241.3 MB 1.9 MB/s eta 0:02:07
# ...

# %%
# !pip install transformers torch sentencepiece datasets scikit-learn pandas numpy matplotlib seaborn

# %%
import torch
from transformers import pipeline

# 감정 분석 모델 로딩
emotion_model = pipeline(
    "text-classification",
    model="tae898/emoberta-base",
    tokenizer="tae898/emoberta-base"
)

# 다이어리 문장
text = "고마워 내 안의 호랑이컴퓨터야. 지켜줘서 너무 고마워."

# 감정 예측
result = emotion_model(text)
print("예측된 감정:", result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 5
#       2 from transformers import pipeline
#       4 # 감정 분석 모델 로딩
# ----> 5 emotion_model = pipeline(
#       6     "text-classification",
#       7     model="tae898/emoberta-base",
#       8     tokenizer="tae898/emoberta-base"
#       9 )
#      11 # 다이어리 문장
#      12 text = "고마워 내 안의 호랑이컴퓨터야. 지켜줘서 너무 고마워."
#
# File ~\anaconda3\Lib\site-packages\transformers\pipelines\__init__.py:1018, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, framework, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#    1013         raise ValueError(
#    1014             'You cannot use both `pipeline(... dtype=..., model_kwargs={"dtype":...})` as those'
#    1015             " arguments might conflict, use only one.)"
# ...

# %%
from transformers import pipeline

emotion_model = pipeline("text-classification", model="tae898/emoberta-base", tokenizer="tae898/emoberta-base")

diary = """
오늘은 마음이 조금 무거웠다. 하지만 작은 희망이 스며들었다.
"""

result = emotion_model(diary)
print("예측된 감정:", result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 3
#       1 from transformers import pipeline
# ----> 3 emotion_model = pipeline("text-classification", model="tae898/emoberta-base", tokenizer="tae898/emoberta-base")
#       5 diary = """
#       6 건강이 최고최고 '가을', 생략 '편의'생략 '우리함께'가을엔 새우깡을 먹어봐요. '잘, 먹고 살자.' 오늘은 마음이 조금 무거웠다. 하지만 작은 희망이 스며들었다.
#       7 """
#       9 result = emotion_model(diary)
#
# File ~\anaconda3\Lib\site-packages\transformers\pipelines\__init__.py:1018, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, framework, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#    1013         raise ValueError(
#    1014             'You cannot use both `pipeline(... dtype=..., model_kwargs={"dtype":...})` as those'
# ...

# %%
import torch
print("PyTorch 버전:", torch.__version__)
# Out:
# PyTorch 버전: 2.8.0+cpu

# %%
import torch
from transformers import pipeline

# 감정 분석 모델 로딩
emotion_model = pipeline(
    "text-classification",
    model="tae898/emoberta-base",
    tokenizer="tae898/emoberta-base",
    framework="pt"  # ← 이게 핵심! PyTorch를 명시적으로 지정
)

# 다이어리 문장
text = "고마워 내 안의 호랑이컴퓨터야. 지켜줘서 너무 고마워."

# 감정 예측
result = emotion_model(text)
print("예측된 감정:", result)
# Out:
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# pytorch_model.bin:   0%|          | 0.00/499M [00:00<?, ?B/s]
# C:\Users\YOONYOO\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\YOONYOO\.cache\huggingface\hub\models--tae898--emoberta-base. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# ...

# %%
# !pip install huggingface_hub[hf_xet]
# Out:
# ...
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.8 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.8 MB 1.2 MB/s eta 0:00:02
#    ----------- ---------------------------- 0.8/2.8 MB 1.2 MB/s eta 0:00:02
#    -------------- ------------------------- 1.0/2.8 MB 1.3 MB/s eta 0:00:02
#    ------------------ --------------------- 1.3/2.8 MB 1.3 MB/s eta 0:00:02
#    ---------------------- ----------------- 1.6/2.8 MB 1.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.1/2.8 MB 1.5 MB/s eta 0:00:01
#    --------------------------------- ------ 2.4/2.8 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 1.6 MB/s eta 0:00:00
# ...

# %%
import torch
from transformers import pipeline

# 감정 분석 모델 로딩
emotion_model = pipeline(
    "text-classification",
    model="tae898/emoberta-base",
    tokenizer="tae898/emoberta-base",
    framework="pt",# ← 이게 핵심! PyTorch를 명시적으로 지정
    max_length=512,        # 최대 길이 설정
    truncation=True        # 초과 시 자동 자르기
)


# 다이어리 문장
text = "고마워 내 안의 호랑이컴퓨터야. 지켜줘서 너무 고마워."

# 감정 예측
result = emotion_model(text)
print("예측된 감정:", result)
# Out:
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Device set to use cpu
# 예측된 감정: [{'label': 'joy', 'score': 0.7702288031578064}]
# C:\Users\YOONYOO\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\YOONYOO\.cache\huggingface\hub\models--tae898--emoberta-base. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# ...

# %%
import time
start = time.time()
import torch 
from transformers import pipeline
emotion_model = pipeline(
    "text-classification",
    model="tae898/emoberta-base",
    tokenizer="tae898/emoberta-base",
    framework="pt",
    max_length=512,        # 최대 길이 설정
    truncation=True        # 초과 시 자동 자르기
)
diary = """ 오늘은 마음이 조금 무거웠다. 하지만 작은 희망이 스며들었다. """
result = emotion_model(diary)  # 감정 분석 실행
print("예측된 감정:", result)  # 결과 출력

end = time.time()
print(f"실행 시간: {end - start:.2f}초")
# Out:
# Device set to use cpu
# 예측된 감정: [{'label': 'joy', 'score': 0.7559447288513184}]
# 실행 시간: 3.22초

# %%
import json

with open (r'
